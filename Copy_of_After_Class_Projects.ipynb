# %% [markdown]
# <a href="https://colab.research.google.com/github/Manraj67/Projects/blob/main/Copy_of_After_Class_Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bob="aug 21"
sukh="feb 10"
harshan="jan 11"
Manraj="jan 16"
rehmat="aug 17"
print(bob)
print(sukh)
print(harshan)
print(Manraj)
print(rehmat)
# Out:
# aug 21
# feb 10
# jan 11
# jan 16
# aug 17

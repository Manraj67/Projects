# %% [markdown]
# <a href="https://colab.research.google.com/github/Manraj67/Projects/blob/main/After_Class_Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bob="aug 21"
sukh="feb 10"
harshan="jan 11"
Manraj="jan 16"
rehmat="aug 17"
print(bob)
print(sukh)
print(harshan)
print(Manraj)
print(rehmat)
# Out:
# aug 21
# feb 10
# jan 11
# jan 16
# aug 17

# %%
abc=input("enter congratulations ")
print(abc.upper())
# Out:
# enter congratulations congratulations
# CONGRATULATIONS

# %%
import math
abc=int(input("type a number "))
print(math.sqrt(abc))
# Out:
# type a number 49
# 7.0

# %%
abc=input("enter a character ")
if abc.isalpha():
  print("input is a character")
else:
  print("input is not a character")
# Out:
# enter a character 67
# input is not a character

# %%
abc=int(input("enter today's temperture "))
if abc>=25:
  print("weather is warm< wear light cloths ")
else:
  print("weather is cold, wear warm cloths")
